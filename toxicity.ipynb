# %% [markdown]
# <a href="https://colab.research.google.com/github/jucrramirez/toxicity_analysis/blob/main/toxicity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def open_csvfile(path):
  dataset = pd.read_csv(path).dropna(how="all")

  dataset["text"] = dataset["text"].apply(
      lambda text:text.encode("latin-1").decode("utf-8")
  )

  return dataset

# %%
train_path = "./datasets/toxicity_train_augmented_senior_20231102.csv"
test_path = "./datasets/toxicity_test_augmented_senior_20231102.csv"

# %%
train_dataset = open_csvfile(train_path)
test_dataset = open_csvfile(test_path)

# %%
train_dataset
# Out:
#                                                       id  \
# 0      https://www.elplural.com/politica/espana/polem...
# 1                                  1.271010900259078e+18
# 2                                 1.2986035925013957e+18
# 3                                 1.2811132626507776e+18
# 4                                  1.465632198984405e+18
# ...                                                  ...
# 10995  https://www.newtral.es/coronavirus-covid-casos...
# 10996  https://www.newtral.es/centros-salud-comunidad...
# 10997  http://www.lavanguardia.com/opinion/20170507/4...
# 10998  http://www.vanitatis.elconfidencial.com/notici...
# 10999  http://www.lavanguardia.com/opinion/20170507/4...
#
#                                                     text  label  \
# 0      Durante su intervención, el vicesecretario de ...      0
# 1      Nueva manipulación a la mujer de la @rfef, dón...      1
# 2      SOLIDARIDAD con los 500 trabajadores de Accion...      1
# ...

# %%
1. Esta nivelado?
2. cuantos textos tienen ambas traducciones?

# %% [markdown]
# # Exploratory data analysis

# %%
train_labels = train_dataset['label'].value_counts().to_dict()
test_labels = test_dataset['label'].value_counts().to_dict()

# %%
labels = [0,1]

plt.bar(labels, train_labels.values(), label='series2', alpha=0.8, color='blue', )
plt.bar(labels, test_labels.values(), label='series1', alpha=0.7, color='red')

plt.show()

# %%
train_dataset.value_counts().plot().bar()
